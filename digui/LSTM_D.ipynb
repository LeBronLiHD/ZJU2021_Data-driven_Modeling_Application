# %%
import copy
import numpy as np
import pandas as pd
# 显示所有列
pd.set_option('display.max_columns', None)
# 显示所有行
pd.set_option('display.max_rows', None)
#datacleaning()

# 读取数据
a=np.loadtxt('train_input.csv',dtype=np.float64)
b=np.loadtxt('output.txt',dtype=np.float64)

b1 = pd.DataFrame(b).shift(-1)
b1 = np.array(b1)
print(b1.shape)
b2 = b
print(b2.shape)
b = b1[:,0]-b2
b = np.delete(b,-1,axis=0)
b.shape
# Out:
# (1596, 1)
# (1596,)
# (1595,)

# %%
b = b[:,np.newaxis]

a[5] =(a[6]+a[5])/2
a = np.delete(a,6,axis=1)
a = np.delete(a,0,axis=0)

#按行拼接，训练集输出也是信息
values=np.concatenate((a,b),axis=1)
#深复制而非浅复制，很有意思的
data = copy.deepcopy(values)
data = pd.DataFrame(data)
def series_to_supervised(data, n_in, n_out):
    df = pd.DataFrame(data)
    n_vars = df.shape[1]  # n_vars 列数
    cols, names = list(), list()

    # 时间间隔跨度, 时间点个数，共 n_in 个
    # 首先添加当前时刻之前的时间点
    for i in range(n_in - 1, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # 然后添加当前时刻
    cols.append(df)
    names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]

    # 添加 target 为未来 n_out 分钟后时刻的温度
    cols.append(df.shift(-n_out))
    names += [('var%d(t+%d)' % (j + 1, n_out)) for j in range(n_vars)]

    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # 删除缺失值
    agg.dropna(inplace=True)
    return agg
# 确保所有数据是 float64 类型
data = data.astype('float64')
# data

# %%
# 构建成监督学习数据集
# 比如根据当前时刻及之前100时刻的数据预测下一个时刻
# 这实际上是在获取 t - n_in + 1 时刻到 t 时刻共 n_in 个特征和第 t + n_out 时刻目标值
number1=50
number2=1

# %%
reframed = series_to_supervised(data, number1, number2)
reframed.head()
print(reframed.shape)
# reframed
# Out:
# (1545, 357)

# %%
#丢弃我们不想预测的列,这里预测的是最后一列，丢弃其他列
drop_col = [number1*7, number1*7+1, number1*7+2, number1*7+3, number1*7+4, number1*7+5]
reframed.drop(reframed.columns[drop_col], axis=1, inplace=True)
# reframed.head()

# %%
# 把数据分为训练集和测试集
values = reframed.values
print(values.shape)
# Out:
# (1545, 351)

# %%
test = values[:int(values.shape[0]*0.2), :]
train = values[int(values.shape[0]*0.2):, :]

# 把数据分为输入和输出
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# 把输入重塑成符合LSTM输入的3D格式 [样例， 时间步, 特征]
train_X = train_X.reshape((train_X.shape[0], number1, 7))
test_X = test_X.reshape((test_X.shape[0], number1, 7))

print("训练集数据 shape:", train_X.shape)
print("训练集标签 shape:", train_y.shape)
print("测试集数据 shape:", test_X.shape)
print("测试集标签 shape:", test_y.shape)
# Out:
# 训练集数据 shape: (1236, 50, 7)
# 训练集标签 shape: (1236,)
# 测试集数据 shape: (309, 50, 7)
# 测试集标签 shape: (309,)

# %%
epochs=50
batch_size = 32
learning_rate = 0.001
patience=3

# %%
import math
from keras.losses import mean_squared_error
from keras.callbacks import ReduceLROnPlateau
from keras.optimizer_v2.adam import Adam
from matplotlib import pyplot as plt
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from keras.layers import Dropout, LSTM, Activation

# 搭建lstm网络模型，activation="RELU"
model = Sequential()
model.add(LSTM(units=64, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Activation("tanh"))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))
# model.add(SimpleRNN(units=64, return_sequences=False))
# model.add(Dropout(0.5))
model.add(Dense(32))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])
model.summary()


lrate = ReduceLROnPlateau(monitor= 'val_loss',min_lr=0.00001,patience=patience,factor=0.5)
# 拟合网络，batch_size默认32
history = model.fit(train_X,
                    train_y,
                    epochs = epochs,
                    batch_size=batch_size,
                    validation_data=(test_X, test_y),
                    callbacks=lrate,
                    verbose=1,
                    shuffle=True)
# 保存模型
model.save('results/LSTMD.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 64)            18432
# _________________________________________________________________
# activation (Activation)      (None, 50, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 53,569
# Trainable params: 53,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 39/39 [==============================] - 4s 47ms/step - loss: 0.0048 - accuracy: 8.0906e-04 - val_loss: 2.7338e-04 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 39/39 [==============================] - 2s 39ms/step - loss: 4.9975e-04 - accuracy: 8.0906e-04 - val_loss: 1.1791e-04 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 39/39 [==============================] - 1s 37ms/step - loss: 3.5644e-04 - accuracy: 8.0906e-04 - val_loss: 1.0936e-04 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 39/39 [==============================] - 1s 36ms/step - loss: 2.8453e-04 - accuracy: 8.0906e-04 - val_loss: 9.1338e-05 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 39/39 [==============================] - 1s 36ms/step - loss: 2.7930e-04 - accuracy: 8.0906e-04 - val_loss: 9.4016e-05 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 39/39 [==============================] - 1s 35ms/step - loss: 2.4406e-04 - accuracy: 8.0906e-04 - val_loss: 8.5742e-05 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 39/39 [==============================] - 1s 34ms/step - loss: 2.0947e-04 - accuracy: 8.0906e-04 - val_loss: 8.1815e-05 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 39/39 [==============================] - 1s 32ms/step - loss: 2.0648e-04 - accuracy: 8.0906e-04 - val_loss: 7.9958e-05 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.8561e-04 - accuracy: 8.0906e-04 - val_loss: 7.8466e-05 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.7795e-04 - accuracy: 8.0906e-04 - val_loss: 7.7018e-05 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.9933e-04 - accuracy: 8.0906e-04 - val_loss: 7.5742e-05 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 39/39 [==============================] - 1s 32ms/step - loss: 1.7668e-04 - accuracy: 8.0906e-04 - val_loss: 7.6136e-05 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.7173e-04 - accuracy: 8.0906e-04 - val_loss: 7.6219e-05 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.6781e-04 - accuracy: 8.0906e-04 - val_loss: 7.5515e-05 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.6748e-04 - accuracy: 8.0906e-04 - val_loss: 7.3485e-05 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.7214e-04 - accuracy: 8.0906e-04 - val_loss: 7.3247e-05 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.6397e-04 - accuracy: 8.0906e-04 - val_loss: 7.2920e-05 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 39/39 [==============================] - 1s 29ms/step - loss: 1.6452e-04 - accuracy: 8.0906e-04 - val_loss: 7.3218e-05 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.6178e-04 - accuracy: 8.0906e-04 - val_loss: 7.2657e-05 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5213e-04 - accuracy: 8.0906e-04 - val_loss: 7.2811e-05 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.6287e-04 - accuracy: 8.0906e-04 - val_loss: 7.2603e-05 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 39/39 [==============================] - 1s 33ms/step - loss: 1.5662e-04 - accuracy: 8.0906e-04 - val_loss: 7.2882e-05 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 39/39 [==============================] - 1s 35ms/step - loss: 1.5196e-04 - accuracy: 8.0906e-04 - val_loss: 7.2425e-05 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5570e-04 - accuracy: 8.0906e-04 - val_loss: 7.2447e-05 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.5191e-04 - accuracy: 8.0906e-04 - val_loss: 7.2292e-05 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.5712e-04 - accuracy: 8.0906e-04 - val_loss: 7.2306e-05 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 39/39 [==============================] - 1s 32ms/step - loss: 1.5798e-04 - accuracy: 8.0906e-04 - val_loss: 7.2367e-05 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 39/39 [==============================] - 1s 29ms/step - loss: 1.6153e-04 - accuracy: 8.0906e-04 - val_loss: 7.2226e-05 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 39/39 [==============================] - 1s 32ms/step - loss: 1.6127e-04 - accuracy: 8.0906e-04 - val_loss: 7.2288e-05 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.4715e-04 - accuracy: 8.0906e-04 - val_loss: 7.2053e-05 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5692e-04 - accuracy: 8.0906e-04 - val_loss: 7.2284e-05 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.6367e-04 - accuracy: 8.0906e-04 - val_loss: 7.1966e-05 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.6367e-04 - accuracy: 8.0906e-04 - val_loss: 7.2300e-05 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.5511e-04 - accuracy: 8.0906e-04 - val_loss: 7.1834e-05 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5679e-04 - accuracy: 8.0906e-04 - val_loss: 7.1745e-05 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.4613e-04 - accuracy: 8.0906e-04 - val_loss: 7.1696e-05 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.4681e-04 - accuracy: 8.0906e-04 - val_loss: 7.1677e-05 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.5617e-04 - accuracy: 8.0906e-04 - val_loss: 7.1607e-05 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 39/39 [==============================] - 1s 33ms/step - loss: 1.5084e-04 - accuracy: 8.0906e-04 - val_loss: 7.1574e-05 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5555e-04 - accuracy: 8.0906e-04 - val_loss: 7.1547e-05 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 39/39 [==============================] - 1s 30ms/step - loss: 1.5299e-04 - accuracy: 8.0906e-04 - val_loss: 7.1561e-05 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 39/39 [==============================] - 1s 34ms/step - loss: 1.5989e-04 - accuracy: 8.0906e-04 - val_loss: 7.1370e-05 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5421e-04 - accuracy: 8.0906e-04 - val_loss: 7.1278e-05 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5146e-04 - accuracy: 8.0906e-04 - val_loss: 7.1175e-05 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.5665e-04 - accuracy: 8.0906e-04 - val_loss: 7.1119e-05 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 39/39 [==============================] - 1s 31ms/step - loss: 1.4626e-04 - accuracy: 8.0906e-04 - val_loss: 7.1255e-05 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 39/39 [==============================] - 1s 34ms/step - loss: 1.5726e-04 - accuracy: 8.0906e-04 - val_loss: 7.1013e-05 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 39/39 [==============================] - 1s 32ms/step - loss: 1.5039e-04 - accuracy: 8.0906e-04 - val_loss: 7.0997e-05 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 39/39 [==============================] - 1s 34ms/step - loss: 1.6176e-04 - accuracy: 8.0906e-04 - val_loss: 7.0954e-05 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 39/39 [==============================] - 2s 40ms/step - loss: 1.4793e-04 - accuracy: 8.0906e-04 - val_loss: 7.1111e-05 - val_accuracy: 0.0000e+00

# %%
# 绘制历史数据
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
# 模型评估
score = model.evaluate(test_X, test_y, verbose=0)
print(score)
# 观察结果
# Out:
# [7.111093873390928e-05, 0.0]

# %%
from tensorflow.keras.models import load_model
# 加载模型调入测试集尝试一下
model_path = 'results/LSTMD.h5'
model = load_model(model_path)

predicted_data = model.predict(test_X)
print(test_y.shape)
print(predicted_data.shape)
print(predicted_data[:,0].shape)
# predicted_data
# Out:
# (309,)
# (309, 1)
# (309,)

# %%
fig = plt.figure(facecolor='white')
ax = fig.add_subplot(211)
ax.plot(test_y, label='True Data')
ax.plot(predicted_data[:,0], label='Prediction_1')
ax.legend()
plt.show()

# %%
pre_1_dim = predicted_data[:,0]

# %%
rmse = math.sqrt(mean_squared_error(test_y,pre_1_dim))
print("模型的RMSE:{}".format(round(rmse,3)))
# Out:
# 模型的RMSE:0.008

# %%
# 读取数据输出结果
def predict(sequence):
    # 数据处理
    sequence = sequence.astype('float64')
    sequence = np.expand_dims(sequence, 0).repeat(1, axis=0)
    # print(sequence.shape)
    pre_t = model.predict(sequence)
    pre_t = np.float64(pre_t)
    return pre_t

a=np.loadtxt('train_input.csv',dtype=np.float64)
a[5] =(a[6]+a[5])/2
a = np.delete(a,6,axis=1)
b=np.loadtxt('output.txt',dtype=np.float64)
b = b[:,np.newaxis]
c=np.loadtxt('test_input.csv',dtype=np.float64)
c[5] = (c[5]+c[6])/2
c = np.delete(c,6,axis=1)
d=np.ones([798,1], dtype = np.float64)
y0 = b[-1,0]
print(y0)
# Out:
# 0.15219002

# %%
values=np.concatenate((a,b),axis=1)
values2=np.concatenate((c,d),axis=1)
values = values[-number1:,:]
print(values.shape)
print(values2.shape)
# values
# Out:
# (50, 7)
# (798, 7)

# %%
for i in range(798):
    # print(predict(values))
    pre=predict(values)
    d[i] = pre
    print(d[i])

    values = np.delete(values, 0, axis = 0)
    values2[i,6]=d[i]+y0
    y0=y0+d[i]
    print("___"+str(y0))
    e = values2[i]
    e = e[np.newaxis,:]
    #print(e.shape)
    values=np.concatenate((values,e),axis=0)
    #print(values.shape)
data = pd.DataFrame(values2)
writer = pd.ExcelWriter('results/TESTLSTM.xlsx')
data.to_excel(writer, 'page_1', float_format='%.32f')		# ‘page_1’是写入excel的sheet名
writer.save()
writer.close()
# Out:
# [0.03407125]
# ___[0.18626127]
# [0.03819748]
# ___[0.22445876]
# [0.04020142]
# ___[0.26466017]
# [0.03999255]
# ___[0.30465273]
# [0.04004592]
# ___[0.34469865]
# [0.04068388]
# ___[0.38538253]
# [0.04232441]
# ___[0.42770694]
# [0.04481978]
# ___[0.47252672]
# [0.04796332]
# ___[0.52049003]
# [0.05194765]
# ___[0.57243768]
# [0.05677347]
# ___[0.62921115]
# [0.06218798]
# ___[0.69139913]
# [0.06807435]
# ___[0.75947347]
# [0.07416711]
# ___[0.83364058]
# [0.08043234]
# ___[0.91407292]
# [0.086644]
# ___[1.00071693]
# [0.09301975]
# ___[1.09373667]
# [0.09945525]
# ___[1.19319192]
# [0.10598383]
# ___[1.29917576]
# [0.11317009]
# ___[1.41234585]
# [0.12046431]
# ___[1.53281016]
# [0.12708634]
# ___[1.6598965]
# [0.13317321]
# ___[1.79306971]
# [0.13878414]
# ___[1.93185385]
# [0.14392439]
# ___[2.07577824]
# [0.14867966]
# ___[2.2244579]
# [0.15322252]
# ___[2.37768041]
# [0.15771879]
# ___[2.53539921]
# [0.16514255]
# ___[2.70054176]
# [0.17369474]
# ___[2.8742365]
# [0.18310915]
# ___[3.05734565]
# [0.19230635]
# ___[3.24965201]
# [0.20123051]
# ___[3.45088252]
# [0.20974593]
# ___[3.66062845]
# [0.21780407]
# ___[3.87843252]
# [0.22554091]
# ___[4.10397343]
# [0.23275776]
# ___[4.33673119]
# [0.23959379]
# ___[4.57632498]
# [0.24638581]
# ___[4.82271079]
# [0.25263703]
# ___[5.07534782]
# [0.25881499]
# ___[5.33416281]
# [0.26451817]
# ___[5.59868098]
# [0.26960853]
# ___[5.86828951]
# [0.27413949]
# ___[6.142429]
# [0.27798986]
# ___[6.42041887]
# [0.28112337]
# ___[6.70154224]
# [0.28365669]
# ___[6.98519892]
# [0.28567466]
# ___[7.27087359]
# [0.28694668]
# ___[7.55782027]
# [0.28758213]
# ___[7.8454024]
# [0.28778031]
# ___[8.13318271]
# [0.2875348]
# ___[8.42071752]
# [0.28681248]
# ___[8.70753]
# [0.28567275]
# ___[8.99320275]
# [0.28416878]
# ___[9.27737153]
# [0.28238669]
# ___[9.55975823]
# [0.28035057]
# ___[9.84010879]
# [0.27809688]
# ___[10.11820568]
# [0.27555364]
# ___[10.39375932]
# [0.2728208]
# ___[10.66658012]
# [0.2700901]
# ___[10.93667022]
# [0.26739034]
# ___[11.20406056]
# [0.26472458]
# ___[11.46878515]
# [0.26204541]
# ___[11.73083056]
# [0.25930348]
# ___[11.99013404]
# [0.25654098]
# ___[12.24667502]
# [0.25374743]
# ___[12.50042246]
# [0.25100687]
# ___[12.75142933]
# [0.24837947]
# ___[12.9998088]
# [0.24571216]
# ___[13.24552096]
# [0.24316046]
# ___[13.48868141]
# [0.24086104]
# ___[13.72954246]
# [0.23862495]
# ___[13.9681674]
# [0.23637809]
# ___[14.20454549]
# [0.23425122]
# ___[14.43879671]
# [0.23209448]
# ___[14.67089119]
# [0.23001514]
# ___[14.90090633]
# [0.22792946]
# ___[15.12883579]
# [0.22607353]
# ___[15.35490932]
# [0.22411008]
# ___[15.57901941]
# [0.22220384]
# ___[15.80122324]
# [0.2203778]
# ___[16.02160105]
# [0.21856546]
# ___[16.24016651]
# [0.21666501]
# ___[16.45683152]
# [0.2147996]
# ___[16.67163112]
# [0.21296346]
# ___[16.88459458]
# [0.211164]
# ___[17.09575858]
# [0.20938721]
# ___[17.30514579]
# [0.20769127]
# ___[17.51283706]
# [0.20601739]
# ___[17.71885445]
# [0.20434152]
# ___[17.92319597]
# [0.20267314]
# ___[18.1258691]
# [0.20103776]
# ___[18.32690687]
# [0.19939002]
# ___[18.52629689]
# [0.19777527]
# ___[18.72407217]
# [0.19608088]
# ___[18.92015305]
# [0.19445081]
# ___[19.11460386]
# [0.19285543]
# ___[19.30745929]
# [0.19127749]
# ___[19.49873678]
# [0.18973006]
# ___[19.68846684]
# [0.18821573]
# ___[19.87668257]
# [0.18681027]
# ___[20.06349284]
# [0.18535599]
# ___[20.24884883]
# [0.1839468]
# ___[20.43279564]
# [0.18259887]
# ___[20.61539451]
# [0.18133587]
# ___[20.79673038]
# [0.18004309]
# ___[20.97677346]
# [0.17875992]
# ___[21.15553338]
# [0.17762111]
# ___[21.33315449]
# [0.17639974]
# ___[21.50955423]
# [0.17519854]
# ___[21.68475277]
# [0.17405707]
# ___[21.85880984]
# [0.17301692]
# ___[22.03182676]
# [0.17200549]
# ___[22.20383225]
# [0.1710164]
# ___[22.37484864]
# [0.17011447]
# ___[22.54496312]
# [0.1692034]
# ___[22.71416652]
# [0.16831784]
# ___[22.88248436]
# [0.16738488]
# ___[23.04986923]
# [0.1664532]
# ___[23.21632243]
# [0.16555806]
# ___[23.38188049]
# [0.16469489]
# ___[23.54657538]
# [0.16391686]
# ___[23.71049223]
# [0.16319454]
# ___[23.87368677]
# [0.16248278]
# ___[24.03616955]
# [0.16175798]
# ___[24.19792753]
# [0.16109677]
# ___[24.3590243]
# [0.16032097]
# ___[24.51934526]
# [0.15961319]
# ___[24.67895845]
# [0.15889721]
# ___[24.83785566]
# [0.15832509]
# ___[24.99618075]
# [0.15773143]
# ___[25.15391218]
# [0.15719457]
# ___[25.31110675]
# [0.15663725]
# ___[25.467744]
# [0.15607558]
# ___[25.62381958]
# [0.15550494]
# ___[25.77932453]
# [0.15492673]
# ___[25.93425126]
# [0.15441225]
# ___[26.08866351]
# [0.1539049]
# ___[26.24256841]
# [0.1534109]
# ___[26.39597931]
# [0.15288389]
# ___[26.5488632]
# [0.15232563]
# ___[26.70118883]
# [0.15181617]
# ___[26.853005]
# [0.15136512]
# ___[27.00437012]
# [0.1508922]
# ___[27.15526232]
# [0.15040824]
# ___[27.30567055]
# [0.15000369]
# ___[27.45567424]
# [0.14956869]
# ___[27.60524293]
# [0.14922792]
# ___[27.75447085]
# [0.1488215]
# ___[27.90329235]
# [0.14840114]
# ___[28.05169349]
# [0.14803061]
# ___[28.1997241]
# [0.14767282]
# ___[28.34739692]
# [0.14728706]
# ___[28.49468398]
# [0.14694607]
# ___[28.64163005]
# [0.14658298]
# ___[28.78821302]
# [0.14615698]
# ___[28.93437001]
# [0.14565878]
# ___[29.08002878]
# [0.1452274]
# ___[29.22525618]
# [0.14477627]
# ___[29.37003245]
# [0.14441815]
# ___[29.5144506]
# [0.14413519]
# ___[29.6585858]
# [0.1439212]
# ___[29.80250699]
# [0.14373364]
# ___[29.94624063]
# [0.14344238]
# ___[30.08968301]
# [0.14324829]
# ___[30.2329313]
# [0.1429159]
# ___[30.3758472]
# [0.14265065]
# ___[30.51849785]
# [0.14243609]
# ___[30.66093394]
# [0.14218307]
# ___[30.803117]
# [0.14195473]
# ___[30.94507174]
# [0.14174251]
# ___[31.08681425]
# [0.14158618]
# ___[31.22840043]
# [0.1414648]
# ___[31.36986523]
# [0.14128825]
# ___[31.51115348]
# [0.14111277]
# ___[31.65226626]
# [0.14098166]
# ___[31.79324792]
# [0.14074212]
# ___[31.93399004]
# [0.14063066]
# ___[32.0746207]
# [0.14043014]
# ___[32.21505084]
# [0.14023897]
# ___[32.35528981]
# [0.1401466]
# ___[32.49543641]
# [0.13999473]
# ___[32.63543113]
# [0.13980412]
# ___[32.77523526]
# [0.13959242]
# ___[32.91482768]
# [0.13933553]
# ___[33.05416321]
# [0.13911913]
# ___[33.19328235]
# [0.13892432]
# ___[33.33220666]
# [0.138836]
# ___[33.47104266]
# [0.13875589]
# ___[33.60979854]
# [0.13860202]
# ___[33.74840056]
# [0.13848621]
# ___[33.88688677]
# [0.13834386]
# ___[34.02523063]
# [0.13813238]
# ___[34.163363]
# [0.13789345]
# ___[34.30125646]
# [0.13776693]
# ___[34.43902338]
# [0.13761617]
# ___[34.57663956]
# [0.13751683]
# ___[34.71415638]
# [0.13736051]
# ___[34.8515169]
# [0.13718863]
# ___[34.98870552]
# [0.13704944]
# ___[35.12575496]
# [0.13693339]
# ___[35.26268835]
# [0.13664326]
# ___[35.39933161]
# [0.13643785]
# ___[35.53576946]
# [0.13616808]
# ___[35.67193753]
# [0.13599306]
# ___[35.8079306]
# [0.13572928]
# ___[35.94365988]
# [0.13554746]
# ___[36.07920734]
# [0.13541551]
# ___[36.21462285]
# [0.13527831]
# ___[36.34990116]
# [0.13512787]
# ___[36.48502904]
# [0.13496126]
# ___[36.6199903]
# [0.13476305]
# ___[36.75475335]
# [0.1345565]
# ___[36.88930985]
# [0.13439982]
# ___[37.02370966]
# [0.13417852]
# ___[37.15788818]
# [0.13405399]
# ___[37.29194217]
# [0.13391542]
# ___[37.4258576]
# [0.13370968]
# ___[37.55956728]
# [0.1334547]
# ___[37.69302198]
# [0.13324712]
# ___[37.8262691]
# [0.13316962]
# ___[37.95943872]
# [0.13301107]
# ___[38.09244979]
# [0.13286847]
# ___[38.22531826]
# [0.13258967]
# ___[38.35790793]
# [0.13245836]
# ___[38.49036629]
# [0.13231862]
# ___[38.6226849]
# [0.13210128]
# ___[38.75478619]
# [0.13196377]
# ___[38.88674996]
# [0.1318344]
# ___[39.01858436]
# [0.13179606]
# ___[39.15038043]
# [0.1317147]
# ___[39.28209513]
# [0.13162035]
# ___[39.41371548]
# [0.13160086]
# ___[39.54531633]
# [0.1315621]
# ___[39.67687843]
# [0.13156481]
# ___[39.80844324]
# [0.13153711]
# ___[39.93998035]
# [0.13145694]
# ___[40.07143729]
# [0.13124059]
# ___[40.20267788]
# [0.13110784]
# ___[40.33378572]
# [0.13095307]
# ___[40.4647388]
# [0.13085978]
# ___[40.59559857]
# [0.13074286]
# ___[40.72634144]
# [0.13071258]
# ___[40.85705402]
# [0.13066624]
# ___[40.98772026]
# [0.13064945]
# ___[41.11836971]
# [0.13063268]
# ___[41.24900239]
# [0.13057195]
# ___[41.37957434]
# [0.13041876]
# ___[41.5099931]
# [0.13034408]
# ___[41.64033718]
# [0.13026467]
# ___[41.77060185]
# [0.13016005]
# ___[41.9007619]
# [0.13016663]
# ___[42.03092853]
# [0.13017322]
# ___[42.16110175]
# [0.13018548]
# ___[42.29128724]
# [0.13019629]
# ___[42.42148353]
# [0.13029793]
# ___[42.55178145]
# [0.1302885]
# ___[42.68206995]
# [0.13029264]
# ___[42.81236259]
# [0.13024049]
# ___[42.94260308]
# [0.13019611]
# ___[43.07279918]
# [0.13006037]
# ___[43.20285956]
# [0.12993024]
# ___[43.3327898]
# [0.12991931]
# ___[43.46270911]
# [0.12996057]
# ___[43.59266967]
# [0.12997323]
# ___[43.72264291]
# [0.12999898]
# ___[43.85264189]
# [0.12994817]
# ___[43.98259006]
# [0.12992693]
# ___[44.11251699]
# [0.12988374]
# ___[44.24240073]
# [0.12986377]
# ___[44.3722645]
# [0.12986727]
# ___[44.50213177]
# [0.12984647]
# ___[44.63197824]
# [0.12980904]
# ___[44.76178727]
# [0.12985438]
# ___[44.89164166]
# [0.12983204]
# ___[45.0214737]
# [0.12987582]
# ___[45.15134952]
# [0.1299562]
# ___[45.28130572]
# [0.12999181]
# ___[45.41129754]
# [0.13008316]
# ___[45.5413807]
# [0.13009463]
# ___[45.67147533]
# [0.13006844]
# ___[45.80154377]
# [0.13008082]
# ___[45.93162459]
# [0.13007824]
# ___[46.06170283]
# [0.13006131]
# ___[46.19176414]
# [0.13013746]
# ___[46.3219016]
# [0.13021277]
# ___[46.45211437]
# [0.1303222]
# ___[46.58243657]
# [0.13048214]
# ___[46.71291871]
# [0.13049978]
# ___[46.84341849]
# [0.13043292]
# ___[46.97385141]
# [0.13052623]
# ___[47.10437764]
# [0.13064945]
# ___[47.23502708]
# [0.13071287]
# ___[47.36573995]
# [0.13080916]
# ___[47.49654911]
# [0.13094816]
# ___[47.62749726]
# [0.1309873]
# ___[47.75848457]
# [0.1310437]
# ___[47.88952827]
# [0.13117015]
# ___[48.02069842]
# [0.13125576]
# ___[48.15195418]
# [0.13127701]
# ___[48.28323119]
# [0.13131021]
# ___[48.4145414]
# [0.13142364]
# ___[48.54596504]
# [0.13153173]
# ___[48.67749677]
# [0.13161212]
# ___[48.80910889]
# [0.13168435]
# ___[48.94079324]
# [0.13184904]
# ___[49.07264228]
# [0.13193507]
# ___[49.20457735]
# [0.131974]
# ___[49.33655135]
# [0.13188961]
# ___[49.46844096]
# [0.13215432]
# ___[49.60059527]
# [0.13213913]
# ___[49.73273441]
# [0.13218476]
# ___[49.86491916]
# [0.13230242]
# ___[49.99722158]
# [0.1322497]
# ___[50.12947128]
# [0.1323369]
# ___[50.26180818]
# [0.13242197]
# ___[50.39423015]
# [0.13258992]
# ___[50.52682007]
# [0.13270877]
# ___[50.65952885]
# [0.13289116]
# ___[50.79242001]
# [0.13300364]
# ___[50.92542365]
# [0.13297275]
# ___[51.05839639]
# [0.13296975]
# ___[51.19136615]
# [0.132789]
# ___[51.32415515]
# [0.13268712]
# ___[51.45684227]
# [0.13255906]
# ___[51.58940133]
# [0.13270396]
# ___[51.72210529]
# [0.13306372]
# ___[51.85516901]
# [0.1333227]
# ___[51.98849171]
# [0.13347487]
# ___[52.12196658]
# [0.13383998]
# ___[52.25580656]
# [0.13408162]
# ___[52.38988818]
# [0.13411458]
# ___[52.52400275]
# [0.13446626]
# ___[52.65846902]
# [0.13463177]
# ___[52.79310078]
# [0.13470475]
# ___[52.92780554]
# [0.13480541]
# ___[53.06261095]
# [0.13481618]
# ___[53.19742713]
# [0.13507727]
# ___[53.3325044]
# [0.1351945]
# ___[53.4676989]
# [0.13523029]
# ___[53.60292918]
# [0.13525863]
# ___[53.73818781]
# [0.13537796]
# ___[53.87356577]
# [0.13552214]
# ___[54.00908791]
# [0.13565379]
# ___[54.14474171]
# [0.13591515]
# ___[54.28065685]
# [0.13614629]
# ___[54.41680315]
# [0.13626316]
# ___[54.55306631]
# [0.13638489]
# ___[54.6894512]
# [0.13653028]
# ___[54.82598148]
# [0.13660799]
# ___[54.96258947]
# [0.13679439]
# ___[55.09938385]
# [0.13698657]
# ___[55.23637042]
# [0.13695121]
# ___[55.37332163]
# [0.13711339]
# ___[55.51043502]
# [0.13721231]
# ___[55.64764733]
# [0.13721749]
# ___[55.78486482]
# [0.13716288]
# ___[55.9220277]
# [0.13718854]
# ___[56.05921624]
# [0.13714543]
# ___[56.19636167]
# [0.13719508]
# ___[56.33355675]
# [0.13724372]
# ___[56.47080047]
# [0.13745731]
# ___[56.60825778]
# [0.13753235]
# ___[56.74579013]
# [0.13755505]
# ___[56.88334518]
# [0.13757531]
# ___[57.02092049]
# [0.13766515]
# ___[57.15858565]
# [0.13777862]
# ___[57.29636427]
# [0.13791534]
# ___[57.43427961]
# [0.13803002]
# ___[57.57230964]
# [0.13818496]
# ___[57.7104946]
# [0.138347]
# ___[57.8488416]
# [0.13846028]
# ___[57.98730188]
# [0.13867825]
# ___[58.12598013]
# [0.13886912]
# ___[58.26484925]
# [0.13914399]
# ___[58.40399324]
# [0.13939892]
# ___[58.54339216]
# [0.13965285]
# ___[58.68304501]
# [0.13988365]
# ___[58.82292866]
# [0.14009096]
# ___[58.96301962]
# [0.14028423]
# ___[59.10330384]
# [0.14037818]
# ___[59.24368202]
# [0.14045127]
# ___[59.38413329]
# [0.14068317]
# ___[59.52481646]
# [0.14080535]
# ___[59.66562181]
# [0.1409492]
# ___[59.80657102]
# [0.14111528]
# ___[59.94768629]
# [0.14113685]
# ___[60.08882315]
# [0.14135416]
# ___[60.23017731]
# [0.14152864]
# ___[60.37170594]
# [0.14175016]
# ___[60.5134561]
# [0.14175315]
# ___[60.65520925]
# [0.14175358]
# ___[60.79696284]
# [0.14185925]
# ___[60.93882208]
# [0.14197977]
# ___[61.08080185]
# [0.14209333]
# ___[61.22289518]
# [0.14232238]
# ___[61.36521756]
# [0.14253074]
# ___[61.5077483]
# [0.14254883]
# ___[61.65029713]
# [0.14263986]
# ___[61.79293699]
# [0.14280707]
# ___[61.93574406]
# [0.142792]
# ___[62.07853606]
# [0.14285266]
# ___[62.22138872]
# [0.14286417]
# ___[62.36425289]
# [0.1429138]
# ___[62.50716669]
# [0.14302364]
# ___[62.65019033]
# [0.14305177]
# ___[62.79324211]
# [0.14296634]
# ___[62.93620845]
# [0.14290333]
# ___[63.07911178]
# [0.14266904]
# ___[63.22178082]
# [0.14266749]
# ___[63.3644483]
# [0.14266366]
# ___[63.50711196]
# [0.14259744]
# ___[63.6497094]
# [0.14259455]
# ___[63.79230394]
# [0.14267677]
# ___[63.93498071]
# [0.14269319]
# ___[64.07767391]
# [0.14262295]
# ___[64.22029685]
# [0.14248848]
# ___[64.36278533]
# [0.14235783]
# ___[64.50514316]
# [0.1422704]
# ___[64.64741356]
# [0.14233343]
# ___[64.78974699]
# [0.14245646]
# ___[64.93220345]
# [0.14271423]
# ___[65.07491768]
# [0.14283445]
# ___[65.21775214]
# [0.14300911]
# ___[65.36076125]
# [0.14306375]
# ___[65.503825]
# [0.14308022]
# ___[65.64690522]
# [0.14297411]
# ___[65.78987933]
# [0.14273778]
# ___[65.93261711]
# [0.14268287]
# ___[66.07529997]
# [0.14258969]
# ___[66.21788966]
# [0.14255106]
# ___[66.36044073]
# [0.14244844]
# ___[66.50288917]
# [0.14244162]
# ___[66.64533078]
# [0.14231202]
# ___[66.7876428]
# [0.14219408]
# ___[66.92983688]
# [0.14222753]
# ___[67.07206441]
# [0.14226387]
# ___[67.21432828]
# [0.14229064]
# ___[67.35661892]
# [0.14232586]
# ___[67.49894478]
# [0.14243309]
# ___[67.64137788]
# [0.14245333]
# ___[67.7838312]
# [0.14252633]
# ___[67.92635753]
# [0.14255501]
# ___[68.06891254]
# [0.1426117]
# ___[68.21152424]
# [0.14271514]
# ___[68.35423938]
# [0.14283101]
# ___[68.4970704]
# [0.14284523]
# ___[68.63991562]
# [0.14290051]
# ___[68.78281614]
# [0.14294189]
# ___[68.92575803]
# [0.14303008]
# ___[69.06878811]
# [0.14319725]
# ___[69.21198536]
# [0.14337502]
# ___[69.35536038]
# [0.1436051]
# ___[69.49896548]
# [0.1435705]
# ___[69.64253598]
# [0.14361046]
# ___[69.78614644]
# [0.1436733]
# ___[69.92981974]
# [0.14366302]
# ___[70.07348276]
# [0.14367215]
# ___[70.21715491]
# [0.14365891]
# ___[70.36081382]
# [0.14372036]
# ___[70.50453418]
# [0.14362177]
# ___[70.64815595]
# [0.14360645]
# ___[70.79176241]
# [0.14358021]
# ___[70.93534262]
# [0.14335158]
# ___[71.0786942]
# [0.14343983]
# ___[71.22213403]
# [0.14339188]
# ___[71.36552591]
# [0.14335383]
# ___[71.50887975]
# [0.14330964]
# ___[71.65218938]
# [0.14335704]
# ___[71.79554642]
# [0.1433704]
# ___[71.93891683]
# [0.14323802]
# ___[72.08215485]
# [0.1431725]
# ___[72.22532735]
# [0.14311188]
# ___[72.36843924]
# [0.14287196]
# ___[72.5113112]
# [0.14264642]
# ___[72.65395761]
# [0.14251693]
# ___[72.79647454]
# [0.14252576]
# ___[72.9390003]
# [0.14252388]
# ___[73.08152419]
# [0.14258084]
# ___[73.22410502]
# [0.14279349]
# ___[73.36689852]
# [0.14279157]
# ___[73.50969009]
# [0.14282337]
# ___[73.65251345]
# [0.14283988]
# ___[73.79535333]
# [0.14276533]
# ___[73.93811866]
# [0.1427322]
# ___[74.08085086]
# [0.14259651]
# ___[74.22344738]
# [0.14251056]
# ___[74.36595794]
# [0.14247088]
# ___[74.50842882]
# [0.14245266]
# ___[74.65088148]
# [0.14233218]
# ___[74.79321366]
# [0.14231351]
# ___[74.93552717]
# [0.14241293]
# ___[75.0779401]
# [0.14241906]
# ___[75.22035916]
# [0.1424733]
# ___[75.36283245]
# [0.14256224]
# ___[75.50539469]
# [0.14253633]
# ___[75.64793102]
# [0.1425097]
# ___[75.79044072]
# [0.14248578]
# ___[75.9329265]
# [0.14244337]
# ___[76.07536987]
# [0.14238472]
# ___[76.2177546]
# [0.14231096]
# ___[76.36006556]
# [0.14219028]
# ___[76.50225584]
# [0.14208162]
# ___[76.64433745]
# [0.14204867]
# ___[76.78638613]
# [0.14147107]
# ___[76.9278572]
# [0.14162211]
# ___[77.06947931]
# [0.14172348]
# ___[77.21120279]
# [0.14180504]
# ___[77.35300783]
# [0.1418398]
# ___[77.49484763]
# [0.14177465]
# ___[77.63662229]
# [0.14173575]
# ___[77.77835804]
# [0.14165436]
# ___[77.92001239]
# [0.14169662]
# ___[78.06170901]
# [0.14171435]
# ___[78.20342336]
# [0.14167383]
# ___[78.34509719]
# [0.14165063]
# ___[78.48674783]
# [0.14161026]
# ___[78.62835809]
# [0.14154893]
# ___[78.76990702]
# [0.14140792]
# ___[78.91131494]
# [0.14141715]
# ___[79.05273209]
# [0.14133753]
# ___[79.19406962]
# [0.14130111]
# ___[79.33537073]
# [0.14127386]
# ___[79.47664458]
# [0.14114848]
# ___[79.61779306]
# [0.14092948]
# ___[79.75872254]
# [0.14090426]
# ___[79.8996268]
# [0.14081301]
# ___[80.04043981]
# [0.1406603]
# ___[80.18110011]
# [0.14066747]
# ___[80.32176758]
# [0.14061122]
# ___[80.46237879]
# [0.14056015]
# ___[80.60293894]
# [0.14057787]
# ___[80.74351681]
# [0.14061895]
# ___[80.88413576]
# [0.14066248]
# ___[81.02479824]
# [0.1406659]
# ___[81.16546414]
# [0.14085354]
# ___[81.30631768]
# [0.14092311]
# ___[81.44724079]
# [0.14084604]
# ___[81.58808684]
# [0.14072654]
# ___[81.72881337]
# [0.14057386]
# ___[81.86938723]
# [0.14040767]
# ___[82.0097949]
# [0.14029382]
# ___[82.15008872]
# [0.14019784]
# ___[82.29028656]
# [0.14011921]
# ___[82.43040577]
# [0.14016075]
# ___[82.57056653]
# [0.14020678]
# ___[82.71077331]
# [0.14016886]
# ___[82.85094217]
# [0.14024672]
# ___[82.99118889]
# [0.14022808]
# ___[83.13141697]
# [0.14024043]
# ___[83.2716574]
# [0.14019248]
# ___[83.41184988]
# [0.14011881]
# ___[83.55196869]
# [0.14004332]
# ___[83.69201201]
# [0.13998483]
# ___[83.83199684]
# [0.13992912]
# ___[83.97192595]
# [0.13987373]
# ___[84.11179968]
# [0.13983712]
# ___[84.2516368]
# [0.13977157]
# ___[84.39140836]
# [0.13975632]
# ___[84.53116468]
# [0.13970311]
# ___[84.67086779]
# [0.13964558]
# ___[84.81051337]
# [0.13958091]
# ___[84.95009428]
# [0.13957828]
# ___[85.08967256]
# [0.13965182]
# ___[85.22932438]
# [0.13972141]
# ___[85.36904579]
# [0.13972694]
# ___[85.50877272]
# [0.13971867]
# ___[85.64849139]
# [0.139617]
# ___[85.78810839]
# [0.13951649]
# ___[85.92762488]
# [0.13946415]
# ___[86.06708903]
# [0.13939212]
# ___[86.20648115]
# [0.13934311]
# ___[86.34582427]
# [0.13918468]
# ___[86.48500895]
# [0.13912469]
# ___[86.62413364]
# [0.13906215]
# ___[86.76319579]
# [0.13897355]
# ___[86.90216934]
# [0.13891384]
# ___[87.04108318]
# [0.13882676]
# ___[87.17990994]
# [0.13881093]
# ___[87.31872087]
# [0.13879827]
# ___[87.45751914]
# [0.13867007]
# ___[87.59618921]
# [0.13843675]
# ___[87.73462596]
# [0.1382858]
# ___[87.87291176]
# [0.13809587]
# ___[88.01100763]
# [0.13798063]
# ___[88.14898826]
# [0.13798702]
# ___[88.28697527]
# [0.13788025]
# ___[88.42485552]
# [0.13784568]
# ___[88.5627012]
# [0.13783857]
# ___[88.70053978]
# [0.13769446]
# ___[88.83823424]
# [0.13753749]
# ___[88.97577173]
# [0.13745309]
# ___[89.11322483]
# [0.13740313]
# ___[89.25062796]
# [0.13731484]
# ___[89.3879428]
# [0.13732551]
# ___[89.52526831]
# [0.13729781]
# ___[89.66256612]
# [0.1374899]
# ___[89.80005602]
# [0.13750768]
# ___[89.9375637]
# [0.13745376]
# ___[90.07501746]
# [0.13763845]
# ___[90.21265591]
# [0.13766697]
# ___[90.35032288]
# [0.13767536]
# ___[90.48799824]
# [0.13768816]
# ___[90.6256864]
# [0.13767655]
# ___[90.76336295]
# [0.13751718]
# ___[90.90088014]
# [0.13740101]
# ___[91.03828115]
# [0.13736252]
# ___[91.17564368]
# [0.13724734]
# ___[91.31289102]
# [0.13724954]
# ___[91.45014056]
# [0.13714778]
# ___[91.58728834]
# [0.13715197]
# ___[91.72444032]
# [0.1371673]
# ___[91.86160762]
# [0.13715209]
# ___[91.99875971]
# [0.13711469]
# ___[92.1358744]
# [0.13709308]
# ___[92.27296748]
# [0.13714531]
# ___[92.41011279]
# [0.13718201]
# ___[92.5472948]
# [0.13722028]
# ___[92.68451508]
# [0.13724716]
# ___[92.82176224]
# [0.13725491]
# ___[92.95901715]
# [0.13727747]
# ___[93.09629462]
# [0.13728957]
# ___[93.23358419]
# [0.13744508]
# ___[93.37102927]
# [0.13764378]
# ___[93.50867305]
# [0.13761477]
# ___[93.64628782]
# [0.1377254]
# ___[93.78401322]
# [0.13785909]
# ___[93.92187231]
# [0.13792199]
# ___[94.0597943]
# [0.13802023]
# ___[94.19781453]
# [0.13783354]
# ___[94.33564807]
# [0.13747677]
# ___[94.47312484]
# [0.13693185]
# ___[94.61005669]
# [0.1364883]
# ___[94.746545]
# [0.136264]
# ___[94.88280899]
# [0.13621794]
# ___[95.01902693]
# [0.13618268]
# ___[95.15520961]
# [0.13615826]
# ___[95.29136787]
# [0.13621342]
# ___[95.42758129]
# [0.13642094]
# ___[95.56400222]
# [0.13647743]
# ___[95.70047965]
# [0.13675213]
# ___[95.83723178]
# [0.13699211]
# ___[95.97422389]
# [0.13701977]
# ___[96.11124366]
# [0.13693935]
# ___[96.24818301]
# [0.1368591]
# ___[96.38504211]
# [0.13669284]
# ___[96.52173495]
# [0.13651863]
# ___[96.65825357]
# [0.13648885]
# ___[96.79474243]
# [0.13644327]
# ___[96.9311857]
# [0.13639556]
# ___[97.06758126]
# [0.13628352]
# ___[97.20386478]
# [0.13617121]
# ___[97.34003598]
# [0.13609053]
# ___[97.47612652]
# [0.13610508]
# ___[97.61223159]
# [0.13603455]
# ___[97.74826614]
# [0.13599613]
# ___[97.88426227]
# [0.13597231]
# ___[98.02023458]
# [0.13586159]
# ___[98.15609617]
# [0.13576643]
# ___[98.2918626]
# [0.13569538]
# ___[98.42755798]
# [0.13573606]
# ___[98.56329405]
# [0.13580658]
# ___[98.69910062]
# [0.13592045]
# ___[98.83502107]
# [0.1360471]
# ___[98.97106817]
# [0.1360632]
# ___[99.10713137]
# [0.1361604]
# ___[99.24329177]
# [0.13609131]
# ___[99.37938308]
# [0.1361555]
# ___[99.51553858]
# [0.13624643]
# ___[99.65178501]
# [0.13610061]
# ___[99.78788562]
# [0.13592345]
# ___[99.92380906]
# [0.13580792]
# ___[100.05961698]
# [0.13577518]
# ___[100.19539216]
# [0.13564293]
# ___[100.33103509]
# [0.13540012]
# ___[100.4664352]
# [0.13515642]
# ___[100.60159163]
# [0.13500579]
# ___[100.73659741]
# [0.13486378]
# ___[100.87146119]
# [0.13477546]
# ___[101.00623665]
# [0.13468091]
# ___[101.14091756]
# [0.13461538]
# ___[101.27553294]
# [0.13456626]
# ___[101.4100992]
# [0.13444141]
# ___[101.54454061]
# [0.13432039]
# ___[101.678861]
# [0.13434651]
# ___[101.81320752]
# [0.13431689]
# ___[101.94752441]
# [0.13422932]
# ___[102.08175372]
# [0.13419159]
# ___[102.21594531]
# [0.134196]
# ___[102.35014131]
# [0.13412854]
# ___[102.48426985]
# [0.13409311]
# ___[102.61836296]
# [0.13410707]
# ___[102.75247003]
# [0.13407086]
# ___[102.88654088]
# [0.13398297]
# ___[103.02052386]
# [0.13415517]
# ___[103.15467902]
# [0.13433154]
# ___[103.28901056]
# [0.13436404]
# ___[103.4233746]
# [0.13428999]
# ___[103.5576646]
# [0.13409689]
# ___[103.69176149]
# [0.13397823]
# ___[103.82573972]
# [0.1338471]
# ___[103.95958682]
# [0.13367099]
# ___[104.09325781]
# [0.13366733]
# ___[104.22692514]
# [0.13360931]
# ___[104.36053445]
# [0.13352785]
# ___[104.4940623]
# [0.13345997]
# ___[104.62752227]
# [0.13331299]
# ___[104.76083525]
# [0.13332768]
# ___[104.89416293]
# [0.13355185]
# ___[105.02771478]
# [0.13358864]
# ___[105.16130342]
# [0.13358463]
# ___[105.29488806]
# [0.13350539]
# ___[105.42839345]
# [0.13341916]
# ___[105.5618126]
# [0.13331512]
# ___[105.69512772]
# [0.13328855]
# ___[105.82841627]
# [0.13330391]
# ___[105.96172018]
# [0.13317798]
# ___[106.09489816]
# [0.13326317]
# ___[106.22816133]
# [0.13328959]
# ___[106.36145092]
# [0.13324584]
# ___[106.49469676]
# [0.13318843]
# ___[106.62788519]
# [0.13305965]
# ___[106.76094484]
# [0.13297655]
# ___[106.89392138]
# [0.13296691]
# ___[107.02688829]
# [0.13295411]
# ___[107.1598424]
# [0.13299182]
# ___[107.29283422]
# [0.13307317]
# ___[107.42590738]
# [0.13317688]
# ___[107.55908426]
# [0.13321562]
# ___[107.69229988]
# [0.13318169]
# ___[107.82548157]
# [0.13320257]
# ___[107.95868414]
# [0.13322553]
# ___[108.09190967]
# [0.1331397]
# ___[108.22504937]
# [0.13309571]
# ___[108.35814508]
# [0.133003]
# ___[108.49114808]
# [0.13296182]
# ___[108.6241099]
# [0.13291913]
# ___[108.75702904]
# [0.13290331]
# ___[108.88993234]
# [0.13294151]
# ___[109.02287386]
# [0.13298701]
# ___[109.15586087]
# [0.13293459]
# ___[109.28879545]
# [0.13278122]
# ___[109.42157667]
# [0.13263302]
# ___[109.55420969]
# [0.13246498]
# ___[109.68667466]
# [0.13229384]
# ___[109.8189685]
# [0.13222358]
# ___[109.95119208]
# [0.13215873]
# ___[110.0833508]
# [0.13222219]
# ___[110.21557299]
# [0.13229288]
# ___[110.34786587]
# [0.13256325]
# ___[110.48042912]
# [0.1325971]
# ___[110.61302623]
# [0.13262245]
# ___[110.74564868]
# [0.13266215]
# ___[110.87831082]
# [0.1328388]
# ___[111.01114962]
# [0.13299486]
# ___[111.14414448]
# [0.13309404]
# ___[111.27723853]
# [0.13293703]
# ___[111.41017556]
# [0.13269389]
# ___[111.54286944]
# [0.13237095]
# ___[111.67524039]
# [0.13220541]
# ___[111.8074458]
# [0.13218266]
# ___[111.93962846]
# [0.13203436]
# ___[112.07166282]
# [0.13191853]
# ___[112.20358136]
# [0.13175766]
# ___[112.33533902]
# [0.13169244]
# ___[112.46703146]
# [0.13159993]
# ___[112.59863139]
# [0.13159847]
# ___[112.73022986]
# [0.13142376]
# ___[112.86165362]
# [0.13131657]
# ___[112.99297019]
# [0.1312499]
# ___[113.1242201]
# [0.13123694]
# ___[113.25545704]
# [0.13109897]
# ___[113.38655601]
# [0.1311968]
# ___[113.51775281]
# [0.13132608]
# ___[113.64907888]
# [0.13145165]
# ___[113.78053054]
# [0.13149567]
# ___[113.91202621]
# [0.13163082]
# ___[114.04365703]
# [0.13191715]
# ___[114.17557418]
# [0.13212061]
# ___[114.30769479]
# [0.13205728]
# ___[114.43975207]
# [0.13204329]
# ___[114.57179535]
# [0.13203096]
# ___[114.70382632]
# [0.13192995]
# ___[114.83575627]
# [0.13192512]
# ___[114.96768139]
# [0.13190983]
# ___[115.09959122]
# [0.13185003]
# ___[115.23144125]
# [0.13178633]
# ___[115.36322759]
# [0.1317056]
# ___[115.49493318]
# [0.13151449]
# ___[115.62644767]
# [0.13139848]
# ___[115.75784616]
# [0.13132423]
# ___[115.88917039]
# [0.1312613]
# ___[116.02043169]
# [0.13109361]
# ___[116.1515253]
# [0.13093761]
# ___[116.2824629]
# [0.13075836]
# ___[116.41322126]
# [0.13067226]
# ___[116.54389353]
# [0.13066994]
# ___[116.67456346]
