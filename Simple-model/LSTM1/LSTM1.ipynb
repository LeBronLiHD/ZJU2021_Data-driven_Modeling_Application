# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
#读取数据并作归一化
train_input=np.loadtxt('train_input.csv',dtype=np.float32)
output=np.loadtxt('train_output.txt',dtype=np.float32)

data_train = pd.DataFrame(train_input)
data_train = scaler.fit_transform(data_train)
data_train=pd.DataFrame(data_train)

data_output = pd.DataFrame(output)
data_output = scaler.fit_transform(data_output)
data_output=pd.DataFrame(data_output)

# %%
#训练集data_train
data_train.describe()
# Out:
#                  0            1            2            3            4  \
# count  1596.000000  1596.000000  1596.000000  1596.000000  1596.000000
# mean      0.322107     0.305525     0.586366     0.385056     0.686711
# std       0.117697     0.077334     0.213634     0.142155     0.110435
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.258915     0.254889     0.461105     0.259662     0.659194
# 50%       0.298229     0.303683     0.629019     0.383048     0.709249
# 75%       0.357324     0.355139     0.734439     0.475519     0.740653
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  5            6
# count  1596.000000  1596.000000
# mean      0.636723     0.622949
# std       0.173591     0.180328
# min       0.000000     0.000000
# 25%       0.508643     0.488976
# 50%       0.686391     0.672994
# 75%       0.764788     0.760008
# max       1.000000     1.000000

# %%
#训练集输出data_output
data_output.describe()
# Out:
#                  0
# count  1596.000000
# mean      0.243713
# std       0.140205
# min       0.000000
# 25%       0.162410
# 50%       0.230348
# 75%       0.283353
# max       1.000000

# %%
#测试集data_test
test_input=np.loadtxt('test_input.csv',dtype=np.float32)
data_test=pd.DataFrame(test_input)
data_test.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  798.000000  798.000000  798.000000  798.000000  798.000000  798.000000
# mean     0.318162    0.671336    0.635381    0.352880    0.590518    0.505869
# std      0.110888    0.089310    0.163356    0.139398    0.143132    0.122946
# min      0.040359    0.069706    0.174480    0.000282    0.001254    0.015904
# 25%      0.258632    0.667248    0.540616    0.356817    0.531069    0.431870
# 50%      0.305694    0.685670    0.625669    0.364310    0.619416    0.493043
# 75%      0.360664    0.702688    0.749234    0.375248    0.690804    0.570393
# max      0.978455    0.782632    0.965611    0.996916    0.897153    0.926988
#
#                 6
# count  798.000000
# mean     0.469130
# std      0.117271
# min      0.010062
# 25%      0.395936
# 50%      0.466510
# 75%      0.534970
# max      0.851098

# %%
data_train = np.expand_dims(data_train,axis=-1)
data_train = np.array(data_train)
data_output = np.array(data_output)
data_train
data_output
# Out:
# array([[0.16440192],
#        [0.16116911],
#        [0.15759481],
#        ...,
#        [0.13142903],
#        [0.13250434],
#        [0.13575165]], dtype=float32)

# %%
from keras.models import Sequential
from keras.layers import Bidirectional,LSTM
from keras.layers.core import Dense, Activation, Dropout
import time

# %%
#搭建1层的LSTM
model = Sequential() #layers [1,64,128,128,128,64,1]
model.add(LSTM(input_shape=(data_train.shape[1],data_train.shape[2]),
               units=64,return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(input_shape=(None,50),units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.add(Activation("sigmoid"))
# model.add(Activation("sigmoid"))
start = time.time()
model.compile(loss="mse", optimizer="rmsprop")

# %%
len(model.layers)
# Out:
# 12

# %%
history = model.fit(data_train,data_output,
          batch_size=64,
          epochs = 100,
          validation_split=0.2)
print("Compilation Time : ", time.time() - start)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 6s 77ms/step - loss: 0.0328 - val_loss: 0.0179
# Epoch 2/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0219 - val_loss: 0.0149
# Epoch 3/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0221 - val_loss: 0.0154
# Epoch 4/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0218 - val_loss: 0.0150
# Epoch 5/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0219 - val_loss: 0.0155
# Epoch 6/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0219 - val_loss: 0.0152
# Epoch 7/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0220 - val_loss: 0.0156
# Epoch 8/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0214 - val_loss: 0.0149
# Epoch 9/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0212 - val_loss: 0.0155
# Epoch 10/100
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0216 - val_loss: 0.0150
# Epoch 11/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0212 - val_loss: 0.0181
# Epoch 12/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0214 - val_loss: 0.0153
# Epoch 13/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0216 - val_loss: 0.0157
# Epoch 14/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0204 - val_loss: 0.0168
# Epoch 15/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0207 - val_loss: 0.0157
# Epoch 16/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0208 - val_loss: 0.0160
# Epoch 17/100
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0209 - val_loss: 0.0158
# Epoch 18/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0209 - val_loss: 0.0169
# Epoch 19/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0206 - val_loss: 0.0160
# Epoch 20/100
#  - ETA: 0s - loss: 0.0209
# Epoch 21/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0209 - val_loss: 0.0162
# Epoch 22/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0204 - val_loss: 0.0186
# Epoch 23/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0206 - val_loss: 0.0168
# Epoch 24/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0200 - val_loss: 0.0169
# Epoch 25/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0201 - val_loss: 0.0174
# Epoch 26/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0201 - val_loss: 0.0174
# Epoch 27/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0197 - val_loss: 0.0183
# Epoch 28/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0196 - val_loss: 0.0202
# Epoch 29/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0192 - val_loss: 0.0209
# Epoch 30/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0193 - val_loss: 0.0245
# Epoch 31/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0185 - val_loss: 0.0287
# Epoch 32/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0183 - val_loss: 0.0271
# Epoch 33/100
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0183 - val_loss: 0.0287
# Epoch 34/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0176 - val_loss: 0.0424
# Epoch 35/100
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0179 - val_loss: 0.0319
# Epoch 36/100
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0179 - val_loss: 0.0289
# Epoch 37/100
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0167 - val_loss: 0.0371
# Epoch 38/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0162 - val_loss: 0.0376
# Epoch 39/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0146 - val_loss: 0.0560
# Epoch 40/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0149 - val_loss: 0.0402
# Epoch 41/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0147 - val_loss: 0.0519
# Epoch 42/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0144 - val_loss: 0.0412
# Epoch 43/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0140 - val_loss: 0.0399
# Epoch 44/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0136 - val_loss: 0.0393
# Epoch 45/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0133 - val_loss: 0.0439
# Epoch 46/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0134 - val_loss: 0.0387
# Epoch 47/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0127 - val_loss: 0.0533
# Epoch 48/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0131 - val_loss: 0.0485
# Epoch 49/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0134 - val_loss: 0.0406
# Epoch 50/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0123 - val_loss: 0.0626
# Epoch 51/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0124 - val_loss: 0.0439
# Epoch 52/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0115 - val_loss: 0.0455
# Epoch 53/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0128 - val_loss: 0.0518
# Epoch 54/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0111 - val_loss: 0.0490
# Epoch 55/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0120 - val_loss: 0.0485
# Epoch 56/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0115 - val_loss: 0.0485
# Epoch 57/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0117 - val_loss: 0.0516
# Epoch 58/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0111 - val_loss: 0.0439
# Epoch 59/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0126 - val_loss: 0.0654
# Epoch 60/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0112 - val_loss: 0.0558
# Epoch 61/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0107 - val_loss: 0.0465
# Epoch 62/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0123 - val_loss: 0.0472
# Epoch 63/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0109 - val_loss: 0.0431
# Epoch 64/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0102 - val_loss: 0.0508
# Epoch 65/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0104 - val_loss: 0.0479
# Epoch 66/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0118 - val_loss: 0.0461
# Epoch 67/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0111 - val_loss: 0.0478
# Epoch 68/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0107 - val_loss: 0.0440
# Epoch 69/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0104 - val_loss: 0.0467
# Epoch 70/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0111 - val_loss: 0.0427
# Epoch 71/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0109 - val_loss: 0.0467
# Epoch 72/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0113 - val_loss: 0.0424
# Epoch 73/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0104 - val_loss: 0.0555
# Epoch 74/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0105 - val_loss: 0.0546
# Epoch 75/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0107 - val_loss: 0.0510
# Epoch 76/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0123 - val_loss: 0.0466
# Epoch 77/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0105 - val_loss: 0.0381
# Epoch 78/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0121 - val_loss: 0.0410
# Epoch 79/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0099 - val_loss: 0.0439
# Epoch 80/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0099 - val_loss: 0.0492
# Epoch 81/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0104 - val_loss: 0.0514
# Epoch 82/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0095 - val_loss: 0.0445
# Epoch 83/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0097 - val_loss: 0.0481
# Epoch 84/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.0097 - val_loss: 0.0440
# Epoch 85/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0092 - val_loss: 0.0467
# Epoch 86/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0099 - val_loss: 0.0461
# Epoch 87/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0096 - val_loss: 0.0503
# Epoch 88/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0115 - val_loss: 0.0510
# Epoch 89/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0097 - val_loss: 0.0511
# Epoch 90/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0103 - val_loss: 0.0468
# Epoch 91/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0099 - val_loss: 0.0475
# Epoch 92/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0103 - val_loss: 0.0414
# Epoch 93/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0096 - val_loss: 0.0471
# Epoch 94/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0101 - val_loss: 0.0527
# Epoch 95/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0095 - val_loss: 0.0480
# Epoch 96/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0092 - val_loss: 0.0488
# Epoch 97/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0093 - val_loss: 0.0535
# Epoch 98/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0100 - val_loss: 0.0492
# Epoch 99/100
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0111 - val_loss: 0.0510
# Epoch 100/100
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0091 - val_loss: 0.0520
# Compilation Time :  71.48010540008545

# %%
score = model.evaluate(data_train,data_output)
print(score)
from sklearn import metrics
data_pre = model.predict(data_train)
MSE = metrics.mean_squared_error(data_output, data_pre)
print(MSE)
RMSE = metrics.mean_squared_error(data_output, data_pre)**0.5
print(RMSE)
# Out:
# 50/50 [==============================] - 1s 7ms/step - loss: 0.0169
# 0.0169282928109169
# 0.016928293
# 0.13010877299750737

# %%
from matplotlib import pyplot as plt
data_output
data_pre
fig1, ax1 = plt.subplots(figsize=(8,6))
ax1.plot(data_pre, '--', label='data_LSTM')
ax1.plot(data_output, '-',label='data_output')
ax1.legend(loc='best')

# %%
data_test = np.array(data_test)
data_test = np.expand_dims(data_test,axis=-1)
y_test = model.predict(data_test)
# y_test
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(y_test, '-',label='RFPreD')
ax.legend(loc='best')
y_test = pd.DataFrame(y_test)
y_test.index = np.linspace(1,798,798)
y_test.to_csv("test_SP_LSTM.csv")
