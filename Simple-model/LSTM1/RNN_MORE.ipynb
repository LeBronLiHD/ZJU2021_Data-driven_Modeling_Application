# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
#读取数据并作归一化
train_input=np.loadtxt('train_modify.txt',dtype=np.float32)
output=np.loadtxt('output_modify.txt',dtype=np.float32)

data_train = pd.DataFrame(train_input)
data_train = scaler.fit_transform(data_train)
data_train=pd.DataFrame(data_train)

data_output = pd.DataFrame(output)
data_output = scaler.fit_transform(data_output)
data_output=pd.DataFrame(data_output)

# %%
#训练集data_train
data_train.describe()
# Out:
#                 0            1            2            3            4   \
# count  1594.000000  1594.000000  1594.000000  1594.000000  1594.000000
# mean      0.322068     0.132516     0.429098     0.385333     0.527423
# std       0.117379     0.044938     0.157530     0.142487     0.089984
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.258451     0.109636     0.337223     0.259675     0.504016
# 50%       0.297600     0.130657     0.460414     0.383048     0.545324
# 75%       0.357282     0.152946     0.537814     0.476493     0.571079
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   ...  \
# count  1594.000000  1594.000000  1594.000000  1594.000000  1594.000000  ...
# mean      0.517494     0.432747     0.321900     0.132564     0.429096  ...
# std       0.140558     0.125117     0.117567     0.044959     0.157527  ...
# ...

# %%
#训练集输出data_output
data_output.describe()
# Out:
#                  0
# count  1594.000000
# mean      0.243815
# std       0.140264
# min       0.000000
# 25%       0.162434
# 50%       0.230446
# 75%       0.283940
# max       1.000000

# %%
#测试集data_test
test_input=np.loadtxt('test_modify.txt',dtype=np.float32)
data_test=pd.DataFrame(test_input)
data_test.describe()
# Out:
#                0           1           2           3           4           5   \
# count  798.000000  798.000000  798.000000  798.000000  798.000000  798.000000
# mean     0.316946    0.671740    0.636060    0.352182    0.590489    0.506054
# std      0.111345    0.090890    0.163141    0.142608    0.143834    0.123694
# min      0.040359    0.031766    0.174480    0.000282    0.001254    0.015904
# 25%      0.258151    0.667573    0.545045    0.357026    0.531429    0.431870
# 50%      0.305178    0.686002    0.625497    0.364650    0.619565    0.493386
# 75%      0.360525    0.702930    0.749993    0.375342    0.690893    0.570393
# max      1.001941    0.782632    0.965611    1.133764    0.897153    0.926988
#
#                6           7           8           9   ...          11  \
# count  798.000000  798.000000  798.000000  798.000000  ...  798.000000
# mean     0.468946    0.317164    0.671688    0.635871  ...    0.591089
# ...

# %%
data_train = np.expand_dims(data_train,axis=-1)
data_train = np.array(data_train)
data_output = np.array(data_output)
data_train
data_output
# Out:
# array([[0.15759481],
#        [0.15557916],
#        [0.15082073],
#        ...,
#        [0.13142903],
#        [0.13250434],
#        [0.13575165]], dtype=float32)

# %%
from keras.models import Sequential
from keras.layers import Bidirectional,LSTM
from keras.layers.core import Dense, Activation, Dropout
import time

# %%
#搭建1层的LSTM
model = Sequential() #layers [1,64,128,128,128,64,1]
model.add(LSTM(input_shape=(data_train.shape[1],data_train.shape[2]),
               units=64,return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(input_shape=(None,50),units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.add(Activation("sigmoid"))
# model.add(Activation("sigmoid"))
start = time.time()
model.compile(loss="mse", optimizer="rmsprop")

# %%
len(model.layers)
# Out:
# 10

# %%
history = model.fit(data_train,data_output,
          batch_size=64,
          epochs = 100,
          validation_split=0.2)
print("Compilation Time : ", time.time() - start)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 6s 110ms/step - loss: 0.0299 - val_loss: 0.0165
# Epoch 2/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0223 - val_loss: 0.0157
# Epoch 3/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0217 - val_loss: 0.0162
# Epoch 4/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0216 - val_loss: 0.0156
# Epoch 5/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0213 - val_loss: 0.0152
# Epoch 6/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0220 - val_loss: 0.0159
# Epoch 7/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0214 - val_loss: 0.0216
# Epoch 8/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0216 - val_loss: 0.0160
# Epoch 9/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0211 - val_loss: 0.0172
# Epoch 10/100
# ...

# %%
score = model.evaluate(data_train,data_output)
print(score)
from sklearn import metrics
data_pre = model.predict(data_train)
MSE = metrics.mean_squared_error(data_output, data_pre)
print(MSE)
RMSE = metrics.mean_squared_error(data_output, data_pre)**0.5
print(RMSE)
# Out:
# 50/50 [==============================] - 1s 13ms/step - loss: 0.0148
# 0.014833902940154076
# 0.014833901
# 0.12179450347823143

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')
plt.show()

# %%
from matplotlib import pyplot as plt
data_output
data_pre
fig1, ax1 = plt.subplots(figsize=(8,6))
ax1.plot(data_pre, '--', label='data_LSTM')
ax1.plot(data_output, '-',label='data_output')
ax1.legend(loc='best')

# %%
data_test = np.array(data_test)
data_test = np.expand_dims(data_test,axis=-1)
y_test = model.predict(data_test)
# y_test
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(y_test, '-',label='RFPreD')
ax.legend(loc='best')
y_test = pd.DataFrame(y_test)
y_test.index = np.linspace(1,798,798)
y_test.to_csv("test_SP_LSTM.csv")
